# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelAngeloTr/Deep_Learning/blob/main/C2/P2/Detec_frutas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Montar Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Variable de la ruta para el dataset.
BASE_PATH = '/content/drive/MyDrive/miniProyecto2/frutas/dataset'

# %% [markdown]
# # Descomprimir ZIP del dataset

# %%
# Crea carpeta donde descomprimir
# !mkdir -p /content/frutas_dataset

# Descomprime el ZIP
# !unzip -q "/content/drive/MyDrive/miniProyecto2/frutas/dataset/Etiquetado de banano.v4-fruits.yolov8.zip" \
  -d /content/frutas_dataset

# %% [markdown]
# #Instalar dependencias

# %%
# !pip install --upgrade pip
# !pip install ultralytics
# !pip install matplotlib opencv-python-headless
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 63.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %% [markdown]
# variable de ruta para data.yaml

# %%
import os

# Ruta base donde descomprimiste tu ZIP
DATA_DIR = '/content/frutas_dataset'

# Ruta al archivo data.yaml ya corregido
DATA_CFG = os.path.join(DATA_DIR, 'data.yaml')

# Directorios de imágenes (para inspección o pruebas)
TRAIN_DIR = os.path.join(DATA_DIR, 'train/images')
VAL_DIR   = os.path.join(DATA_DIR, 'valid/images')
TEST_DIR  = os.path.join(DATA_DIR, 'test/images')
